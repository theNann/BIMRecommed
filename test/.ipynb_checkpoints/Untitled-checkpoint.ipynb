# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
train_df = pd.read_csv('../input/simlarities_by_pdu.csv')
train_df.tail()
# Out:
#            p_sim  d_sim  u_sim       sim
# 853466  0.074833    1.0    1.0  0.370130
# 853467  0.050641    1.0    1.0  0.043367
# 853468  0.137972    1.0    1.0  0.495652
# 853469  0.073358    1.0    1.0  0.043724
# 853470  0.135429    1.0    1.0  0.028007

# %%
plt.scatter(train_df['p_sim'], train_df['sim'])
plt.show()

# %%
plt.scatter(train_df['d_sim'], train_df['sim'])
plt.show()

# %%
plt.scatter([1,2,3,4], [1, 2, 3, 4])
plt.show()

# %%
train_df['d_sim/p_sim'] = train_df['d_sim'] / train_df['p_sim']
plt.scatter(train_df['d_sim/p_sim'], train_df['sim'])
plt.show()

# %%
train_df['sim'].describe()
# Out:
# count    853471.000000
# mean          0.167644
# std           0.246279
# min           0.000000
# 25%           0.000000
# 50%           0.036413
# 75%           0.267308
# max           1.000000
# Name: sim, dtype: float64

# %%
sns.distplot(train_df['sim'])

# %%
print("Skewness: %f" % train_df['sim'].skew())
print("Kurtosis: %f" % train_df['sim'].kurt())
# Out:
# Skewness: 1.517186
# Kurtosis: 1.229858

# %%
var = 'p_sim'
data = pd.concat([train_df['sim'], train_df[var]], axis=1)
data.plot.scatter(x=var, y='sim', ylim=(0,1));

# %%
var = 'd_sim/p_sim'
data = pd.concat([train_df['sim'], train_df[var]], axis=1)
data.plot.scatter(x=var, y='sim')

# %%
corrmat = train_df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
sns.set()
cols = ['p_sim', 'd_sim', 'u_sim','sim', 'd_sim/p_sim']
sns.pairplot(train_df[cols], size = 2.5)
plt.show();
